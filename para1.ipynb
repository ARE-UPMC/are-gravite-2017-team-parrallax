# %%
from __future__ import division 
import numpy as np
import matplotlib.pyplot as plt
from scipy import *                  
from pylab import * 
import os
# %matplotlib notebook

jour=3600*24
an=365*3600*24
UA=149597870000
k=2*np.pi

def teta(T):
    return k*np.linspace(0, T, 99)/T

RayonT=1*UA
RayonM=1.52*UA
RayonS=696342000
Tterre=1*an
temps0 = 0 
tempsf = 2*an 
p = 175
Tmars=1.88*an
Tsoleil=27.28*jour

def angle(t,T):
    return k*t/T

def PosM(t):
    x = RayonM*np.cos(angle(t,Tmars))
    y = RayonM*np.sin(angle(t,Tmars))
    return [x, y]

def PosT(t): 
    x = RayonT*np.cos(angle(t,Tterre))
    y = RayonT*np.sin(angle(t,Tterre))
    return [x, y]

def parallaxe(t):
    return [m-t for t,m in zip(PosT(t),PosM(t))]

def Terre(Rayon):               
    Terre= plt.Circle((15, 20), Rayon, fc='blue')
    return plt.gca().add_patch(Terre)
Terre(2e10)



for k in range(p): 
    t =60*jour
    plt.plot(parallaxe(t)[0], parallaxe(t)[1], 'o', color='black')
    plt.plot([parallaxe(t)[0]],[parallaxe(t)[1]],'--')
    plt.plot()
    plt.axis('equal') 
    filename = 'fichierTemp'+str('%02d' %k)+'.pdf' 
    savefig(filename)
# Out:
# C:\Python34\lib\site-packages\IPython\kernel\__init__.py:13: ShimWarning: The `IPython.kernel` package has been deprecated. You should import from ipykernel or jupyter_client instead.
#   "You should import from ipykernel or jupyter_client instead.", ShimWarning)
# <img src="data:image/png;base64,...">
